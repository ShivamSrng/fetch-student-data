# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
students_marks_dataframe = pd.read_csv('data/students_marks.csv', nrows=10)
students_marks_dataframe.head()
# Out:
#    Gender  Math score  Reading score  Writing score             Name
# 0  Female          44             58             57   Carla Carrillo
# 1  Female          43             62             61   Marvin Delgado
# 2  Female          76             83             82     Craig Flores
# 3  Female          63             72             68    Kenneth Davis
# 4    Male          94             77             83  Melissa Marquez

# %%
students_marks_dataframe['Total'] = students_marks_dataframe['Math score'] + students_marks_dataframe['Reading score'] + students_marks_dataframe['Writing score']
students_marks_dataframe.head()
# Out:
#    Gender  Math score  Reading score  Writing score             Name  Total
# 0  Female          44             58             57   Carla Carrillo    159
# 1  Female          43             62             61   Marvin Delgado    166
# 2  Female          76             83             82     Craig Flores    241
# 3  Female          63             72             68    Kenneth Davis    203
# 4    Male          94             77             83  Melissa Marquez    254

# %%
students_marks_dataframe['Average Score'] = students_marks_dataframe['Total'] / 3
students_marks_dataframe.head()
# Out:
#    Gender  Math score  Reading score  Writing score             Name  Total  \
# 0  Female          44             58             57   Carla Carrillo    159
# 1  Female          43             62             61   Marvin Delgado    166
# 2  Female          76             83             82     Craig Flores    241
# 3  Female          63             72             68    Kenneth Davis    203
# 4    Male          94             77             83  Melissa Marquez    254
#
#    Average Score
# 0      53.000000
# 1      55.333333
# 2      80.333333
# 3      67.666667
# 4      84.666667

# %%
plt.bar(students_marks_dataframe['Name'], students_marks_dataframe['Math score'])
plt.xlabel('Name')
plt.ylabel('Math Score')
plt.title('Math Scores')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(students_marks_dataframe['Name'], students_marks_dataframe['Reading score'])
plt.xlabel('Name')
plt.ylabel('Reading Score')
plt.title('Reading Scores')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(students_marks_dataframe['Name'], students_marks_dataframe['Writing score'])
plt.xlabel('Name')
plt.ylabel('Writing Score')
plt.title('Writing Scores')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(students_marks_dataframe['Name'], students_marks_dataframe['Average Score'])
plt.xlabel('Name')
plt.ylabel('Average Score')
plt.title('Average Scores')
plt.xticks(rotation=90)
plt.show()

# %%
class_average = students_marks_dataframe['Total'].mean() / 3
print('Class Average:', class_average)
# Out:
# Class Average: 66.7
